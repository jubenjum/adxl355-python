# %%
import pandas as pd

from bokeh.io import output_notebook, show
from bokeh.plotting import figure

import numpy as np
from scipy import signal

output_notebook()

# %matplotlib inline
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1001">Loading BokehJS ...</span>
#     </div>

# %%
df = pd.read_csv('test03.txt', sep=' ', names=['t', 'x', 'y', 'z'])
df.t.diff().mean()
# Out:
# 0.011285757522131687

# %% [raw]
# # in the first tests the samplig was not homogeneous
# #new_timestamps = np.linspace(df.t.min(), df.t.max())
#
# new_timestamps = np.arange(0, df.t.max()-df.t.min(), 0.01)
# x = np.interp(new_timestamps, df.t, df.x)
# y = np.interp(new_timestamps, df.t, df.y)
# z = np.interp(new_timestamps, df.t, df.z)

# %%
### dt = 0.04
sel = df.z
new_t = np.linspace(df.t.min(), df.t.max(), len(df) )# new_timestamps

p = figure(plot_width=800, plot_height=400)
p.line(new_t, (2/(2**20))*sel, line_width=2, line_color='red', legend="000")
show(p)

f, Pxx = signal.welch(sel, 100, nperseg=512, scaling="spectrum")
p = figure(plot_width=800, plot_height=400, y_axis_type="log", x_axis_type="log")
p.line(f, np.sqrt(Pxx), line_width=2, line_color='red', legend="000")
show(p)
# Out:
#   <div class="bk-root" id="9f85371e-22de-49cc-a97b-bc4b68a00417" data-root-id="2126"></div>
#   <div class="bk-root" id="f68967e8-b3ef-4be2-a0aa-cddcef058b20" data-root-id="2307"></div>

# %%
len(np.arange(df.t.min(), df.t.max(), 0.004)), len(df.t), len(df.x)

# %% [markdown]
# ###
